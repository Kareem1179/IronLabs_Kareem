# %%
import requests
receive=requests.get('https://imgs.xkcd.com/comics/proxy_variable.png')
receive.content
receive.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '56001', 'Server': 'nginx', 'Content-Type': 'image/png', 'Last-Modified': 'Sat, 30 Jul 2022 01:36:52 GMT', 'ETag': '"62e48b34-dac1"', 'Expires': 'Wed, 31 Aug 2022 05:44:55 GMT', 'Cache-Control': 'max-age=300', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 31 Aug 2022 07:28:27 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-cdg20781-CDG', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1661930907.218580,VS0,VE308'}

# %%
f = open("Desktop/pic100.png", "wb")
f.write(receive.content)
# Out:
# 56001

# %%
response = requests.get('https://httpbin.org/get')
response.url
# Out:
# 'https://httpbin.org/get'

# %%
p={'things':2}
response=requests.post('https://httpbin.org/get',data=p)
load={'username':'kareem','password':'hello'}
response=requests.get('https://httpbin.org/get',params=load)
response.json()
# Out:
# {'args': {'password': 'hello', 'username': 'kareem'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.27.1',
#   'X-Amzn-Trace-Id': 'Root=1-630f0d9c-362b995c057214b9488230df'},
#  'origin': '195.134.167.217',
#  'url': 'https://httpbin.org/get?username=kareem&password=hello'}

# %%
p={'things':2}
response=requests.post('https://httpbin.org/post',data=p)
response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'things': '2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '8',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.27.1',
#   'X-Amzn-Trace-Id': 'Root=1-630f0d9d-5071eeae562bc9e8636ffadd'},
#  'json': None,
#  'origin': '195.134.167.217',
#  'url': 'https://httpbin.org/post'}

# %%
response = requests.get('https://api.github.com/ironhack-datalabs')
response.content
# Out:
# b'{"message":"Not Found","documentation_url":"https://docs.github.com/rest"}'

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
search['items']
# Out:
# [{'name': '.0016.scavengerhunt',
#   'path': '47222/.0016.scavengerhunt',
#   'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
search['items']
# Out:
# [{'name': '.0016.scavengerhunt',
#   'path': '47222/.0016.scavengerhunt',
#   'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
x['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 x['name']
#
# NameError: name 'x' is not defined

# %%
[items['name']]

# %%
repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()
repo_files_names

# %%
repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls

# %%
repo_files=requests.get('https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476')

# %%
repo_files.content

# %%
repo_files_content=[requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files]

# %%
repo_files=[requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_urls]

# %%
import requests
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search

# %%
repo_files_names=[item['name'] for item in search['items']]
repo_files_names.sort()
repo_files_names
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %%
repo_files_urls={item['name']:item['url'] for item in search['items']}

repo_files_urls
sorted_urls={}
for i in repo_files_names:
    sorted_urls[i]=repo_files_urls[i]
print(sorted_urls)
# Out:
# {'.0001.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0002.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/88596/.0002.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0003.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/60224/.0003.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0004.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/68848/.0004.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0005.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/44639/.0005.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0006.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0007.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/17020/
# ...

# %%
repo_files=[requests.get(sorted_urls[repo_filename]) for repo_filename in sorted_urls]

# %%
repo_files
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
x=requests.get('https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476')

# %%
x.json()
# Out:
# {'name': '.0016.scavengerhunt',
#  'path': '47222/.0016.scavengerhunt',
#  'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#  'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#  'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#  'type': 'file',
#  'content': 'aXMK\n',
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
# ...

# %%
codes=[x.json()['content'] for x in repo_files]

# %%
print(codes)
filtered_codes=codes
# Out:
# ['SW4K\n', 'ZGF0YQo=\n', 'c2NpZW5jZSwK\n', 'ODAK\n', 'cGVyY2VudAo=\n', 'b2YK\n', 'dGltZQo=\n', 'c3BlbnQK\n', 'aXMK\n', 'cHJlcGFyaW5nCg==\n', 'ZGF0YSwK\n', 'MjAK\n', 'cGVyY2VudAo=\n', 'b2YK\n', 'dGltZQo=\n', 'aXMK\n', 'c3BlbnQK\n', 'Y29tcGxhaW5pbmcK\n', 'YWJvdXQK\n', 'dGhlCg==\n', 'bmVlZAo=\n', 'dG8K\n', 'cHJlcGFyZQo=\n', 'ZGF0YS4K\n']

# %%
print(filtered_codes)
type(filtered_codes[0])
# Out:
# ['SW4K\n', 'ZGF0YQo=\n', 'c2NpZW5jZSwK\n', 'ODAK\n', 'cGVyY2VudAo=\n', 'b2YK\n', 'dGltZQo=\n', 'c3BlbnQK\n', 'aXMK\n', 'cHJlcGFyaW5nCg==\n', 'ZGF0YSwK\n', 'MjAK\n', 'cGVyY2VudAo=\n', 'b2YK\n', 'dGltZQo=\n', 'aXMK\n', 'c3BlbnQK\n', 'Y29tcGxhaW5pbmcK\n', 'YWJvdXQK\n', 'dGhlCg==\n', 'bmVlZAo=\n', 'dG8K\n', 'cHJlcGFyZQo=\n', 'ZGF0YS4K\n']
# str

# %%
dec=[base64.decodebytes(k) for k in filtered_codes]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\base64.py:510, in _input_type_check(s)
#     509 try:
# --> 510     m = memoryview(s)
#     511 except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 dec=[base64.decodebytes(k) for k in filtered_codes]
#
# Input In [26], in <listcomp>(.0)
# ----> 1 dec=[base64.decodebytes(k) for k in filtered_codes]
#
# File ~\anaconda3\lib\base64.py:537, in decodebytes(s)
#     535 def decodebytes(s):
#     536     """Decode a bytestring of base-64 data into a bytes object."""
# --> 537     _input_type_check(s)
#     538     return binascii.a2b_base64(s)
#
# ...

# %%
import base64
dec=[base64.decodebytes(k) for k in filtered_codes]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\base64.py:510, in _input_type_check(s)
#     509 try:
# --> 510     m = memoryview(s)
#     511 except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 import base64
# ----> 2 dec=[base64.decodebytes(k) for k in filtered_codes]
#
# Input In [27], in <listcomp>(.0)
#       1 import base64
# ----> 2 dec=[base64.decodebytes(k) for k in filtered_codes]
#
# File ~\anaconda3\lib\base64.py:537, in decodebytes(s)
#     535 def decodebytes(s):
#     536     """Decode a bytestring of base-64 data into a bytes object."""
# --> 537     _input_type_check(s)
# ...

# %%
import base64
  
  

  

sample_string = base64.b64decode("aXMK".encode("ascii")).decode("ascii")
sample_string
# Out:
# 'is\n'

# %%
decoded=[base64.b64decode(i.encode("ascii")).decode("ascii") for i in codes]
decoded
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %%
import base64
message=[]
for base64_message in filtered_codes:
    base64_bytes=base64_message.encode('ascii')
    message_bytes=base64.b64decode(base64_bytes)
    message.append(message_bytes.decode('ascii'))
print(message)
for
# Out:
# ['In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']
