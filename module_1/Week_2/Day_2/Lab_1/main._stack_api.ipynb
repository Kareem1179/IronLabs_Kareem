# %%
pip install stackapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions',fromdate='2022-07-01', todate='2022-07-31')

# %%
question_list=[question['title'] for question in questions['items']]
#answer_list=[answer['title'] for answer in answers['items']]

# %%
print(question_list)
# Out:
# ['Declaring generic type mid-class (not in header) in java, possibly through GenericType class', 'How to directly test a Solidity Library with Hardhat/Chai', 'MountVolume.SetUp failed for volume &quot;argo-artifacts&quot; : secret &quot;argo-artifacts&quot; not found : while building kubeflow pipeline', 'How does Obi app estimates bolt taxi prices', 'Calendar icon on datetime bootstrap picker notshowing', 'ExtractValue : How to retrieve a particular value from an XML tag in SQL table, with a key value that can be retrieved from another table', 'Simple opengl triangle function not drawing anything to screen', '1241: Operand should contain 1 column(s)', 'Gremlin simple path query, to get path based on first edge encountered property', 'MongoDB Atlas not connecting from Kubernetes', 'Fortify fix for Often Misused: Authentication - C#', 'Data studio - cannot add more than 10 dimensions to a blended data source', 'Embed and manage Google Forms in NodeJS app', 'VS Code: Configure keyboard 
# ...

# %%
question_id=[question['question_id'] for question in questions['items']]

# %%
print(question_id)
# Out:
# [73008359, 72936183, 73149716, 72863441, 73177960, 73125516, 73172919, 73118558, 73036082, 73053973, 73135855, 72901771, 73148832, 73173340, 72882381, 73177347, 73006023, 73068818, 73060287, 73154477, 72980735, 73143026, 73064859, 73158839, 73003127, 73074407, 73098125, 73001238, 73161518, 73061074, 73023097, 73085488, 73117484, 73150123, 72867845, 73062460, 73133687, 73061520, 73150935, 73095392, 73073641, 73177982, 73156192, 72869370, 73156243, 73098271, 73120053, 72987147, 73047247, 73138299, 73135422, 73111938, 73002665, 73144536, 73075434, 73170496, 73173157, 73172556, 72824450, 73111496, 72893577, 73116391, 72893373, 72964221, 73111031, 73103201, 72908270, 73176698, 73179426, 73166802, 73158539, 72944366, 72863892, 72883543, 73168573, 73131586, 73086380, 73179104, 73167935, 72894373, 73064328, 73036841, 72896856, 73121777, 72980280, 72994200, 73047736, 73055408, 73132288, 73150370, 73178624, 73175731, 73157123, 72927795, 73168698, 73074739, 73129421, 72831111, 72963888, 7287568
# ...

# %%
questions = SITE.fetch('questions',fromdate='2022-07-01', todate='2022-07-31')

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 290,
#  'total': 0,
#  'items': [{'tags': ['java', 'oop', 'generics'],
#    'owner': {'reputation': 107,
#     'user_id': 13414786,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-R6zLCVHI1qs/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJN0CqQJqxOEuz8yEXyPE5NoNJIwEg/photo.jpg?sz=256',
#     'display_name': 'Ankit',
#     'link': 'https://stackoverflow.com/users/13414786/ankit'},
#    'is_answered': False,
#    'view_count': 39,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1659897515,
#    'creation_date': 1658015227,
#    'last_edit_date': 1658032412,
#    'question_id': 73008359,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73008359/declaring-generic-type-mid-class-not-in-header-in-java-possibly-through-gener',
# ...

# %%
answers = SITE.fetch('questions/{ids}/answers', ids=question_id[:100], filter='withbody')
answer=[a['body'] for a in answers['items']]
answer
# Out:
# ['<p>Figured out an answer to my question... thought I\'d post an answer in case anyone else runs into the same issue.</p>\n<p>It\'s similar to idea 4, aka using .create() methods that call private constuctors.</p>\n<pre class="lang-java prettyprint-override"><code>class PA&lt;E , N extends Number&gt;{\n    public static &lt;D&gt; PA create(Function enc, D ... elements){\n        return create2(enc, elements[0], enc.apply(elements[0]), elements);\n    }\n    public static &lt;D&gt; PA create(D ... elements){\n        Function enc = defaultEncryptor(elements[0]);\n        return create2(enc, elements[0], enc.apply(elements[0]), elements);\n    } \n    private static &lt;D, M&gt; PA create2(Function f, D eUseless, M nUseless, E ... elements){\n        return new PA&lt;D,M&gt;(f, eUseless, nUseless, elements)\n    }\n    private &lt;E,N&gt;PolyArray(Function f, E eUseless, N nUseless, E ... elements){ \n        // constructor stuff\n    }\n\n\n\n    public static &lt;D&gt; Function defa
# ...

# %%
voted_q = SITE.fetch('questions', fromdate="2022-08-01",
    min=5, tagged='python', sort='votes')

# %%
votes=[v['title'] for v in voted_q['items']]

# %%
max_voted_question=votes[0]
print(max_voted_question)
# Out:
# What is the `except*` operator?

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers',ids=['6784','6473'])

# %%
question_id_list=[a['question_id'] for a in answers['items']]
question_id_list
# Out:
# [6778]

# %%
answers1 = SITE.fetch('questions/{ids}/answers', ids=question_id_list, filter='withbody')
answers1
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 265,
#  'total': 0,
#  'items': [{'owner': {'reputation': 7027,
#     'user_id': 247,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://www.gravatar.com/avatar/6e3a808c50751a0f07d105fb4f560277?s=256&d=identicon&r=PG',
#     'display_name': 'Shawn Miller',
#     'link': 'https://stackoverflow.com/users/247/shawn-miller'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1219897406,
#    'last_edit_date': 1219897406,
#    'creation_date': 1219176270,
#    'answer_id': 16830,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5',
# ...

# %%
answers_list=[]
for a in answers1['items']:
    if a['answer_id'] in [6784,6473]:
        answers_list.append(a['body'])

# %%
answers_list
# Out:
# ["<p>Enabling windowless mode (wmode=) makes embedded flash act and render just like other elements. Without that, it's rendered in a seperate step and just overlaid on the browser's window.</p>\n\n<p>Could the flash element be losing focus? Sounds like input focus is moved to the scollbar, then you have to move it back.</p>\n\n<p>Also you weren't clear whether the focus issue was only in FF or also in IE.</p>\n"]
